# %% [markdown]
# R is a statistcal programming language
# Used for data processing and manipulation
# Statistical, data analysis and machine learning
#
# R can import data from flat files, databases, web, and statistical software.
#
# Basic data analysis doesn't require packages.
#
# RStudio is the default R IDE. Increases productivity in running R programming language.
#
# Includes a code editor, a console, a workspace/history tab, and a plots files and help packages tab.
#
# Popular libraries:
# dplyr for data manipulation
# stringr for string manipulation
# ggplot for data visualization
# caret for machine learning

# %% [markdown]
# ggplot - visualization such as histograms, bar charts, scatterplots, etc. Allows adding layer and components on a single visualization.
#
# Plotly - an R package can be used to create web based data visualizations that can be displayed or saved as individual html files.
#
# Lattice - data viz tool that is used to impement complex, multi variable data sets
#
# Leaflet - Popular for creating interactive plots.
#
# to install, use command:
# install.packages("package name")

# %%
cars <- c(1, 4, 6, 5, 10)
plot (cars)
# Out:
# plot without title

# %%
cars <- c(1, 4, 6, 5, 10)
plot (cars, type = "o")
title(main="Cars vs Index")
# Out:
# Plot with title "Cars vs Index"

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y = wt))+geom_point()
# Out:
# plot without title

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y = wt))+geom_point() + ggtitle("Miles per gallon vs weight") + labs(y="weight", x= "miles per gallon")
# Out:
# plot without title
